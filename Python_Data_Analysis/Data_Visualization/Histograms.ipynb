# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from numpy.random import randn
from scipy import stats
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 2.,  7., 11., 13., 14., 18., 10., 13.,  9.,  3.]),
#  array([-2.59906223, -2.09328173, -1.58750123, -1.08172073, -0.57594024,
#         -0.07015974,  0.43562076,  0.94140126,  1.44718176,  1.95296226,
#          2.45874275]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

plt.hist(dataset2,color='indianred')
# Out:
# (array([ 3.,  4.,  7., 11.,  9.,  8., 16., 10.,  6.,  6.]),
#  array([-2.31077397, -1.8786551 , -1.44653622, -1.01441735, -0.58229848,
#         -0.1501796 ,  0.28193927,  0.71405814,  1.14617702,  1.57829589,
#          2.01041476]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)

# 'normed' kwarg deprecated, so we use 'density' instead
# Out:
# (array([0.05785445, 0.1157089 , 0.2314178 , 0.        , 0.17356335,
#         0.2314178 , 0.1157089 , 0.52069006, 0.28927225, 0.2314178 ,
#         0.17356335, 0.28927225, 0.57854451, 0.3471267 , 0.28927225,
#         0.28927225, 0.17356335, 0.17356335, 0.1157089 , 0.2314178 ]),
#  array([-2.31077397, -2.09471453, -1.8786551 , -1.66259566, -1.44653622,
#         -1.23047679, -1.01441735, -0.79835791, -0.58229848, -0.36623904,
#         -0.1501796 ,  0.06587983,  0.28193927,  0.49799871,  0.71405814,
#          0.93011758,  1.14617702,  1.36223645,  1.57829589,  1.79435533,
#          2.01041476]),
#  <a list of 20 Patch objects>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
